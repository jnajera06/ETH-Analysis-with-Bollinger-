# %% [markdown]
# # Trading Ethereum with Bollinger Bands
# *****************

# %% [markdown]
# <div class="alert alert-info">
#
# <strong>TRADING FOR SELL AND BUY ETH WITH BOLLINGER BANDS</strong>
# <br>
#
# What are the Bollinger Bands?
# Bollinger Bands are curves drawn in and around the price structure consisting of a moving average (a middle band), an upper band and a lower band that enable you to identify whether the price of an asset is relatively high or low.
#
# <strong>Every price that overpass the upperband is a good time to sell</strong>
#     <br>
# <strong>Every price that is under the lowerband is a good time to buy</strong>
#     <br>
#     <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info">
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info">
#
# ![image.png](attachment:image.png)

# %%
# !pip install yfinance
# Out:
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# ...
# ERROR: conda 4.11.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.

# %%
 # !pip install ruamel_yaml==0.11.14
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Jose\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Jose\\AppData\\Local\\Temp\\pip-install-zuovr9xf\\ruamel-yaml\\setup.py'"'"'; __file__='"'"'C:\\Users\\Jose\\AppData\\Local\\Temp\\pip-install-zuovr9xf\\ruamel-yaml\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Jose\AppData\Local\Temp\pip-pip-egg-info-idiz1bid'
#          cwd: C:\Users\Jose\AppData\Local\Temp\pip-install-zuovr9xf\ruamel-yaml\
#     Complete output (11 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Jose\AppData\Local\Temp\pip-install-zuovr9xf\ruamel-yaml\setup.py", line 165, in <module>
#         pkg_data = _package_data(__file__.replace('setup.py', '__init__.py'))
# ...

# %%
# !pip install yfinance

# %%
##!jupyter labextension install jupyterlab-plotly@4.14.3

# !pip install plotly

# %%
# !pip install dash

# %%
# !pip install matplotlib

# %%
import yfinance
import pandas as dp
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Type of Cryptocurrencies
#
# * BTC-USD
# * ETH-USD
# * USDT-USD
# * USDC-USD
# * BNB-USD
# * BUSD-USD
# * XRP-USD
# * ADA-USD
# * SOL-USD
# * DOGE-USD
# * DOT-USD
# * HEX-USD
# * DAI-USD
# * MATIC-USD
# * SHIB-USD
# * WTRX-USD
# * TRX-USD
# * AVAX-USD
# * STETH-USD
# * LEO-USD
# * WBTC-USD
# * UNI1-USD
# * ETC-USD
# * YOUC-USD
# * LTC-USD

# %%
## BTC-USD
name = "ETH-EUR"
name2 = "ETH-USD"

# %% [markdown]
# Microsoft Corporation (MSFT)
#
# msft = yfinance.Ticker("MSFT")
#
# #get stock info
#
#     hist = msft.history(period="max")
#     hist

# %%
from datetime import date, timedelta, datetime

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-08-30

# %%
## it create result to add 1 day more to today variable, otherwise the data history just include data
## until one day before today (yesterday), so history with this will be until today.

result = today + timedelta(days=1)
print(result)
# Out:
# 2022-08-31

# %%
ticker = yfinance.Ticker(name2)
#df = ticker.history(interval='1d', start='2021-01-15', end=result)
df = ticker.history(interval='1d', start='2021-01-15', end=(date.today()+timedelta(days=1)))

# %%
##tk2 = yfinance.Ticker('SOL-USD')
##tk2.history()

# %%
##df.head(20)
df.tail(30)
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2022-08-01  1681.445557  1700.170898  1613.416016  1635.195801  16191371176
# 2022-08-02  1634.645874  1672.629761  1567.851074  1632.945435  20426082309
# 2022-08-03  1633.051270  1678.098267  1595.634521  1618.874512  16786218830
# 2022-08-04  1618.886719  1658.511597  1585.326538  1608.205811  14467440626
# 2022-08-05  1607.523926  1732.254639  1606.497070  1732.254639  18546491876
# 2022-08-06  1732.661133  1744.326416  1691.658081  1691.658081  11757911705
# 2022-08-07  1691.777954  1724.789185  1672.908447  1699.350830  10252090340
# 2022-08-08  1699.693481  1806.886475  1697.407959  1775.516113  16841424404
# 2022-08-09  1776.071289  1786.122559  1675.849854  1703.025024  16368619692
# 2022-08-10  1702.906494  1869.400635  1665.090454  1851.742676  23512477984
# 2022-08-11  1851.828369  1927.939209  1851.828369  1881.224121  23826986482
# ...

# %%
period =20
multiplier = 2

# %%
## Calculate Upperband and Lowerband
## every price that overpass the upperband is a good time to sell
## every price that is under the lowerband is a good time to buy

df['UpperBand'] = df['Close'].rolling(period).mean() + df['Close'].rolling(period).std()*multiplier
df['LowerBand'] = df['Close'].rolling(period).mean() - df['Close'].rolling(period).std()*multiplier

# %%
df.tail(20)
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2022-08-11  1851.828369  1927.939209  1851.828369  1881.224121  23826986482
# 2022-08-12  1880.899170  1957.552979  1860.083496  1957.246460  17168141904
# 2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548  16038975216
# 2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002  14062754456
# 2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149  20349931313
# 2022-08-16  1902.833130  1910.745361  1862.273438  1878.139404  15637578930
# 2022-08-17  1877.934326  1951.675659  1823.532227  1832.999634  20308508124
# 2022-08-18  1833.715576  1876.376953  1826.957764  1847.007812  14999352229
# 2022-08-19  1847.095337  1847.095337  1611.338867  1612.987305  25906358731
# 2022-08-20  1612.650635  1652.218750  1534.298828  1577.003784  18334580263
# 2022-08-21  1576.543579  1640.936523  1569.046509  1619.318970  15849221752
# ...

# %%
## every price that overpass the upperband is a good time to sell
## every price that is under the lowerband is a good time to buy

plt.subplots(figsize=(20,10))
plt.plot(df['Close'])
plt.plot(df['UpperBand'])
plt.plot(df['LowerBand'])

# %%
def sell_func(data):
    if(data['Close'] >= data['UpperBand']):
        return data['Close']
def buy_func (data):
    if(data['Close'] <= data['LowerBand']):
        return data['Close']

# %%
df['sell'] = df.apply(lambda row: sell_func(row), axis=1)
df['buy'] = df.apply(lambda row: buy_func(row), axis=1)

# %%
df.tail(20)
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2022-08-11  1851.828369  1927.939209  1851.828369  1881.224121  23826986482
# 2022-08-12  1880.899170  1957.552979  1860.083496  1957.246460  17168141904
# 2022-08-13  1957.333984  2013.755737  1948.595215  1981.336548  16038975216
# 2022-08-14  1981.782471  2022.791504  1919.010132  1936.802002  14062754456
# 2022-08-15  1936.760498  2007.210327  1881.856812  1904.228149  20349931313
# 2022-08-16  1902.833130  1910.745361  1862.273438  1878.139404  15637578930
# 2022-08-17  1877.934326  1951.675659  1823.532227  1832.999634  20308508124
# 2022-08-18  1833.715576  1876.376953  1826.957764  1847.007812  14999352229
# 2022-08-19  1847.095337  1847.095337  1611.338867  1612.987305  25906358731
# 2022-08-20  1612.650635  1652.218750  1534.298828  1577.003784  18334580263
# 2022-08-21  1576.543579  1640.936523  1569.046509  1619.318970  15849221752
# ...

# %%
import plotly.express as px 
import dash
import dash_core_components as dcc
import dash_html_components as html
